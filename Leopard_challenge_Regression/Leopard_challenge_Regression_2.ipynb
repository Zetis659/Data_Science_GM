# %% [markdown]
# # Leopard challenge: Regression

# %% [markdown]
# ## Загрузка данных
# #### Данные беру из leopard-challenge-regression.zip

# %% [markdown]
# https://drive.google.com/file/d/1P3aYu5kdMLOVxgl2K6wjzx-HtWB5J_wu/view?usp=sharing

# %% [markdown]
# # Colab

# %%
! gdown --id 1P3aYu5kdMLOVxgl2K6wjzx-HtWB5J_wu
# Out:
# "gdown" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# ! unzip /content/leopard-challenge-regression.zip -d /content/leopard_challenge_regression/

# %%
! unzip / content / leopard-challenge-regression.zip -d / content / leopard_challenge_regression /
# Out:
# "unzip" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/leopard_challenge_regression/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train = pd.read_csv('/content/leopard_challenge_regression/train.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/leopard_challenge_regression/train.csv'

# %%
train.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
#           CouncilArea  Lattitude Longtitude             Regionname  \
# 0  Yarra City Council   -37.7996   144.9984  Northern Metropolitan
# 1  Yarra City Council   -37.8079   144.9934  Northern Metropolitan
# 2  Yarra City Council   -37.8093   144.9944  Northern Metropolitan
# 3  Yarra City Council   -37.7969   144.9969  Northern Metropolitan
# 4  Yarra City Council   -37.8072   144.9941  Northern Metropolitan
#
#    Propertycount     id
# 0         4019.0  34302
# 1         4019.0  33247
# 2         4019.0  31886
# 3         4019.0  18999
# 4         4019.0  16809
#
# [5 rows x 22 columns]

# %% [markdown]
# # Pycharm

# %%
from zipfile import ZipFile

with ZipFile('leopard-challenge-regression.zip', 'r') as zf:
    zf.extractall()

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
import seaborn as sns

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')
# plt.style.use('seaborn-v0_8-colorblind')

# %%
import numpy as np

# %%
import missingno as msno

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council   -37.7996    144.9984
# 1          79.0     1900.0  Yarra City Council   -37.8079    144.9934
# 2         150.0     1900.0  Yarra City Council   -37.8093    144.9944
# 3           NaN        NaN  Yarra City Council   -37.7969    144.9969
# 4         142.0     2014.0  Yarra City Council   -37.8072    144.9941
#
#               Regionname  Propertycount     id
# 0  Northern Metropolitan         4019.0  34302
# 1  Northern Metropolitan         4019.0  33247
# 2  Northern Metropolitan         4019.0  31886
# 3  Northern Metropolitan         4019.0  18999
# 4  Northern Metropolitan         4019.0  16809

# %%
train.shape
# Out:
# (18373, 22)

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#          Suburb          Address  Rooms Type Method SellerG       Date  \
# 0    Abbotsford  513/6 Acacia Pl      3    u      S  Dingle  7/10/2017
# 1    Abbotsford    60 Charles St      3    h      S  Jellis  7/10/2017
# 2    Abbotsford    38 Studley St      3    h      S  Nelson  7/10/2017
# 3  Airport West     18 Glenys Av      3    h      S   Raine  7/10/2017
# 4  Airport West     35 Thomas St      3    h      S  Nelson  7/10/2017
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       3.0    3067.0       NaN       NaN  NaN       NaN           NaN
# 1       3.0    3067.0       3.0       1.0  NaN     192.0         109.0
# 2       3.0    3067.0       3.0       1.0  1.0     159.0          93.0
# 3      10.4    3042.0       3.0       1.0  5.0     536.0         108.0
# 4      10.4    3042.0       3.0       1.0  1.0       NaN         130.0
#
#    YearBuilt                 CouncilArea  Lattitude  Longtitude  \
# 0        NaN          Yarra City Council        NaN         NaN
# 1     1900.0          Yarra City Council  -37.80792   144.99508
# 2     1890.0          Yarra City Council  -37.80124   144.99459
# 3     1980.0  Moonee Valley City Council  -37.72285   144.87539
# 4     2009.0  Moonee Valley City Council  -37.71754   144.87704
#
#               Regionname  Propertycount     id
# 0  Northern Metropolitan         4019.0  30130
# 1  Northern Metropolitan         4019.0  18311
# 2  Northern Metropolitan         4019.0  18934
# 3   Western Metropolitan         3464.0   1824
# 4   Western Metropolitan         3464.0  31339

# %%
test.shape
# Out:
# (8818, 21)

# %% [markdown]
# #### Перевод даты в datetime

# %%
train.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# id                 int64
# dtype: object

# %%
train.Date = pd.to_datetime(train.Date, format='%d/%m/%Y')

# %%
train.dtypes
# Out:
# Suburb                   object
# Address                  object
# Rooms                     int64
# Type                     object
# Price                   float64
# Method                   object
# SellerG                  object
# Date             datetime64[ns]
# Distance                float64
# Postcode                float64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea              object
# Lattitude               float64
# Longtitude              float64
# Regionname               object
# Propertycount           float64
# id                        int64
# dtype: object

# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## EDA

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18373 entries, 0 to 18372
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         18373 non-null  object
#  1   Address        18373 non-null  object
#  2   Rooms          18373 non-null  int64
#  3   Type           18373 non-null  object
#  4   Price          18373 non-null  float64
#  5   Method         18373 non-null  object
#  6   SellerG        18373 non-null  object
#  7   Date           18373 non-null  datetime64[ns]
#  8   Distance       18373 non-null  float64
#  9   Postcode       18373 non-null  float64
#  10  Bedroom2       14905 non-null  float64
#  11  Bathroom       14903 non-null  float64
#  12  Car            14798 non-null  float64
#  13  Landsize       13579 non-null  float64
#  14  BuildingArea   7750 non-null   float64
#  15  YearBuilt      8944 non-null   float64
#  16  CouncilArea    18372 non-null  object
#  17  Lattitude      15041 non-null  float64
#  18  Longtitude     15041 non-null  float64
#  19  Regionname     18372 non-null  object
#  20  Propertycount  18372 non-null  float64
#  21  id             18373 non-null  int64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(7)
# memory usage: 3.1+ MB

# %% [markdown]
# **Разделю переменные на категориальные и количественные:**

# %%
cat_features = [i for i in train.columns if train[i].dtype == 'object']

# %%
cat_features
# Out:
# ['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'CouncilArea', 'Regionname']

# %%
num_features = [i for i in train.columns if i not in cat_features]

# %%
num_features
# Out:
# ['Rooms',
#  'Price',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'Lattitude',
#  'Longtitude',
#  'Propertycount',
#  'id']

# %% [markdown]
# **Проверю, не потерялись ли колонки:**

# %%
len(train.columns), len(cat_features) + len(num_features)
# Out:
# (22, 22)

# %% [markdown]
# ### Количественные признаки

# %%
num_features
# Out:
# ['Rooms',
#  'Price',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'Lattitude',
#  'Longtitude',
#  'Propertycount',
#  'id']

# %% [markdown]
# **Гистограммы количественных признаков**

# %%
train.hist(figsize=(20, 10));

# %% [markdown]
# **Описание количественных признаков**

# %%
train.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  18373.000000  1.837300e+04  18373.000000  18373.000000  14905.000000
# mean       2.936592  1.053235e+06     10.403962   3107.258314      2.914928
# std        0.955952  6.217973e+05      6.018424     95.285542      0.962743
# min        1.000000  2.270000e+05      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.300000   3046.000000      2.000000
# 50%        3.000000  8.800000e+05      9.700000   3085.000000      3.000000
# 75%        3.000000  1.301000e+06     13.300000   3149.000000      3.000000
# max       12.000000  5.580000e+06     48.100000   3978.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  14903.000000  14798.000000   13579.000000   7750.000000  8944.000000
# mean       1.538683      1.617313     558.937403    151.133167  1965.925089
# std        0.688374      0.957072    3991.516323    519.517626    36.958956
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1950.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    173.862500  2000.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount            id
# count  15041.000000  15041.000000   18372.000000  18373.000000
# mean     -37.809872    144.996486    7518.621489  17490.731889
# std        0.081272      0.106536    4487.143499  10075.864589
# min      -38.182550    144.431810     249.000000      2.000000
# 25%      -37.858180    144.931400    4294.000000   8749.000000
# 50%      -37.803600    145.001100    6567.000000  17497.000000
# 75%      -37.756100    145.060190   10331.000000  26286.000000
# max      -37.408530    145.526350   21650.000000  34856.000000

# %%
train.describe().T.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_a459c_row0_col0, #T_a459c_row1_col0, #T_a459c_row1_col1, #T_a459c_row1_col2, #T_a459c_row1_col3, #T_a459c_row1_col4, #T_a459c_row1_col5, #T_a459c_row1_col6, #T_a459c_row1_col7, #T_a459c_row2_col0, #T_a459c_row3_col0, #T_a459c_row12_col0, #T_a459c_row13_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a459c_row0_col1, #T_a459c_row0_col2, #T_a459c_row0_col3, #T_a459c_row0_col4, #T_a459c_row0_col5, #T_a459c_row0_col6, #T_a459c_row0_col7, #T_a459c_row2_col1, #T_a459c_row2_col2, #T_a459c_row2_col3, #T_a459c_row2_col4, #T_a459c_row2_col5, #T_a459c_row2_col6, #T_a459c_row2_col7, #T_a459c_row3_col1, #T_a459c_row3_col2, #T_a459c_row3_col5, #T_a459c_row3_col6, #T_a459c_row3_col7, #T_a459c_row4_col1, #T_a459c_row4_col2, #T_a459c_row4_col3, #T_a459c_row4_col4, #T_a459c_row4_col5, #T_a459c_row4_col6, #T_a459c_row4_col7, #T_a459c_row5_col1, #T_a459c_row5_col2, #T_a459c_row5_col3, #T_a459c_row5_col4, #T_a459c_row5_col5, #T_a459c_row5_col6, #T_a459c_row5_col7, #T_a459c_row6_col1, #T_a459c_row6_col2, #T_a459c_row6_col3, #T_a459c_row6_col4, #T_a459c_row6_col5, #T_a459c_row6_col6, #T_a459c_row6_col7, #T_a459c_row7_col1, #T_a459c_row7_col3, #T_a459c_row7_col4, #T_a459c_row7_col5, #T_a459c_row7_col6, #T_a459c_row8_col0, #T_a459c_row8_col1, #T_a459c_row8_col2, #T_a459c_row8_col3, #T_a459c_row8_col4, #T_a459c_row8_col5, #T_a459c_row8_col6, #T_a459c_row9_col1, #T_a459c_row9_col2, #T_a459c_row9_col4, #T_a459c_row9_col5, #T_a459c_row9_col6, #T_a459c_row9_col7, #T_a459c_row10_col1, #T_a459c_row10_col2, #T_a459c_row10_col3, #T_a459c_row10_col4, #T_a459c_row10_col5, #T_a459c_row10_col6, #T_a459c_row10_col7, #T_a459c_row11_col1, #T_a459c_row11_col2, #T_a459c_row11_col3, #T_a459c_row11_col4, #T_a459c_row11_col5, #T_a459c_row11_col6, #T_a459c_row11_col7, #T_a459c_row12_col3, #T_a459c_row12_col7, #T_a459c_row13_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_a459c_row3_col3, #T_a459c_row13_col4 {
#   background-color: #038166;
#   color: #f1f1f1;
# }
# #T_a459c_row3_col4, #T_a459c_row7_col2, #T_a459c_row9_col3, #T_a459c_row12_col1, #T_a459c_row12_col2, #T_a459c_row12_col4, #T_a459c_row12_col5, #T_a459c_row13_col7 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_a459c_row4_col0, #T_a459c_row5_col0 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_a459c_row6_col0 {
#   background-color: #a9d466;
#   color: #000000;
# }
# #T_a459c_row7_col0 {
#   background-color: #8cc666;
#   color: #000000;
# }
# #T_a459c_row7_col7 {
#   background-color: #138966;
#   color: #f1f1f1;
# }
# #T_a459c_row8_col7, #T_a459c_row12_col6 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# #T_a459c_row9_col0 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_a459c_row10_col0, #T_a459c_row11_col0 {
#   background-color: #afd766;
#   color: #000000;
# }
# #T_a459c_row13_col1, #T_a459c_row13_col2 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_a459c_row13_col5, #T_a459c_row13_col6 {
#   background-color: #058266;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a459c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a459c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a459c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a459c_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a459c_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a459c_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a459c_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a459c_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a459c_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a459c_level0_row0" class="row_heading level0 row0" >Rooms</th>
#       <td id="T_a459c_row0_col0" class="data row0 col0" >18373.000000</td>
#       <td id="T_a459c_row0_col1" class="data row0 col1" >2.936592</td>
#       <td id="T_a459c_row0_col2" class="data row0 col2" >0.955952</td>
#       <td id="T_a459c_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_a459c_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_a459c_row0_col5" class="data row0 col5" >3.000000</td>
#       <td id="T_a459c_row0_col6" class="data row0 col6" >3.000000</td>
#       <td id="T_a459c_row0_col7" class="data row0 col7" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row1" class="row_heading level0 row1" >Price</th>
#       <td id="T_a459c_row1_col0" class="data row1 col0" >18373.000000</td>
#       <td id="T_a459c_row1_col1" class="data row1 col1" >1053234.882218</td>
#       <td id="T_a459c_row1_col2" class="data row1 col2" >621797.251963</td>
#       <td id="T_a459c_row1_col3" class="data row1 col3" >227000.000000</td>
#       <td id="T_a459c_row1_col4" class="data row1 col4" >635000.000000</td>
#       <td id="T_a459c_row1_col5" class="data row1 col5" >880000.000000</td>
#       <td id="T_a459c_row1_col6" class="data row1 col6" >1301000.000000</td>
#       <td id="T_a459c_row1_col7" class="data row1 col7" >5580000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row2" class="row_heading level0 row2" >Distance</th>
#       <td id="T_a459c_row2_col0" class="data row2 col0" >18373.000000</td>
#       <td id="T_a459c_row2_col1" class="data row2 col1" >10.403962</td>
#       <td id="T_a459c_row2_col2" class="data row2 col2" >6.018424</td>
#       <td id="T_a459c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a459c_row2_col4" class="data row2 col4" >6.300000</td>
#       <td id="T_a459c_row2_col5" class="data row2 col5" >9.700000</td>
#       <td id="T_a459c_row2_col6" class="data row2 col6" >13.300000</td>
#       <td id="T_a459c_row2_col7" class="data row2 col7" >48.100000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row3" class="row_heading level0 row3" >Postcode</th>
#       <td id="T_a459c_row3_col0" class="data row3 col0" >18373.000000</td>
#       <td id="T_a459c_row3_col1" class="data row3 col1" >3107.258314</td>
#       <td id="T_a459c_row3_col2" class="data row3 col2" >95.285542</td>
#       <td id="T_a459c_row3_col3" class="data row3 col3" >3000.000000</td>
#       <td id="T_a459c_row3_col4" class="data row3 col4" >3046.000000</td>
#       <td id="T_a459c_row3_col5" class="data row3 col5" >3085.000000</td>
#       <td id="T_a459c_row3_col6" class="data row3 col6" >3149.000000</td>
#       <td id="T_a459c_row3_col7" class="data row3 col7" >3978.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row4" class="row_heading level0 row4" >Bedroom2</th>
#       <td id="T_a459c_row4_col0" class="data row4 col0" >14905.000000</td>
#       <td id="T_a459c_row4_col1" class="data row4 col1" >2.914928</td>
#       <td id="T_a459c_row4_col2" class="data row4 col2" >0.962743</td>
#       <td id="T_a459c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a459c_row4_col4" class="data row4 col4" >2.000000</td>
#       <td id="T_a459c_row4_col5" class="data row4 col5" >3.000000</td>
#       <td id="T_a459c_row4_col6" class="data row4 col6" >3.000000</td>
#       <td id="T_a459c_row4_col7" class="data row4 col7" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row5" class="row_heading level0 row5" >Bathroom</th>
#       <td id="T_a459c_row5_col0" class="data row5 col0" >14903.000000</td>
#       <td id="T_a459c_row5_col1" class="data row5 col1" >1.538683</td>
#       <td id="T_a459c_row5_col2" class="data row5 col2" >0.688374</td>
#       <td id="T_a459c_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_a459c_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_a459c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a459c_row5_col6" class="data row5 col6" >2.000000</td>
#       <td id="T_a459c_row5_col7" class="data row5 col7" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a459c_level0_row6" class="row_heading level0 row6" >Car</th>
#       <td id="T_a459c_row6_col0" class="data row6 col0" >14798.000000</td>
#       <td id="T_a459c_row6_col1" class="data row6 col1"

# %% [markdown]
# **Функция гистограммы и описания для количественных признаков**

# %%
def hist_box_describe_num(ds, x):
    print(ds[x].describe())
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    sns.histplot(data=ds, x=ds[x], kde=True);
    plt.subplot(1,2,2)
    sns.boxplot(data=ds, y=ds[x]);

# %%
def hist_describe_num(ds, x):
    plt.figure()
    sns.histplot(data=ds, x=ds[x], kde=True);
    print(ds[x].value_counts())

# %% [markdown]
# #### Price - Распределение цены

# %%
train.Price.count()
# Out:
# 18373

# %%
hist_box_describe_num(train, 'Price')
# Out:
# count    1.837300e+04
# mean     1.053235e+06
# std      6.217973e+05
# min      2.270000e+05
# 25%      6.350000e+05
# 50%      8.800000e+05
# 75%      1.301000e+06
# max      5.580000e+06
# Name: Price, dtype: float64

# %% [markdown]
# **Большинство домов оцениваются от 200.000 до 2.2 млн.**
# **Если откинуть стоимость более 4 млн. это ≈0.4% от всех данных**

# %%
hist_box_describe_num(train.query('Price < 4000000'), 'Price')
# Out:
# count    1.829300e+04
# mean     1.037854e+06
# std      5.771145e+05
# min      2.270000e+05
# 25%      6.320000e+05
# 50%      8.800000e+05
# 75%      1.300000e+06
# max      3.970000e+06
# Name: Price, dtype: float64

# %% [markdown]
# **Получается что *абсолютное большинство* домов оцениваются от 600 тыс до 1.3 млн.**

# %% [markdown]
# #### Rooms - Количество комнат

# %%
hist_box_describe_num(train, 'Rooms')
# Out:
# count    18373.000000
# mean         2.936592
# std          0.955952
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         12.000000
# Name: Rooms, dtype: float64

# %% [markdown]
# **Большинство домов имеют от 1 до 4 комнат, а *абсолютное большинство* от 2 до 3**

# %% [markdown]
# #### Date - Дата покупки

# %%
hist_describe_num(train, 'Date')
# Out:
# 2017-05-27    610
# 2017-09-23    591
# 2017-09-16    544
# 2017-06-03    524
# 2017-08-26    522
# 2017-06-17    486
# 2016-11-27    455
# 2017-09-03    450
# 2017-08-12    449
# 2017-06-24    448
# 2017-09-09    446
# 2017-08-19    441
# 2017-03-04    416
# 2017-02-25    414
# 2016-12-10    407
# 2017-07-29    383
# 2016-11-12    381
# 2017-07-01    381
# 2017-03-18    375
# 2016-12-03    360
# 2016-10-15    359
# 2017-07-08    351
# 2017-07-22    350
# 2017-04-08    348
# 2016-06-18    343
# 2016-05-28    340
# 2017-05-20    340
# 2017-07-15    336
# 2016-11-19    336
# 2016-10-08    317
# 2017-05-13    311
# 2016-05-07    309
# 2016-08-28    302
# 2016-09-17    302
# 2016-09-24    298
# 2016-09-10    294
# 2016-06-04    283
# 2016-06-27    277
# 2017-04-29    273
# 2016-09-03    268
# 2016-05-22    266
# 2016-04-16    266
# 2016-05-14    250
# 2016-08-22    240
# 2016-11-07    239
# 2016-07-30    207
# 2017-05-06    190
# 2016-08-06    190
# 2017-04-22    180
# 2016-07-16    177
# 2016-08-13    175
# 2016-07-26    167
# 2016-04-23    135
# 2017-02-11    111
# 2016-06-12     58
# 2017-03-11     48
# 2016-02-04     34
# 2017-09-30     18
# 2016-01-28      2
# Name: Date, dtype: int64

# %% [markdown]
# ???

# %% [markdown]
# #### Distance - Расстояние до центра

# %%
hist_box_describe_num(train, 'Distance')
# Out:
# count    18373.000000
# mean        10.403962
# std          6.018424
# min          0.000000
# 25%          6.300000
# 50%          9.700000
# 75%         13.300000
# max         48.100000
# Name: Distance, dtype: float64

# %% [markdown]
# **Большинство домов находятся от 0 до 24 км от центра**
# **Если откинуть расстояние более 33 км, что составляет ≈1% всех данных**

# %%
hist_box_describe_num(train.query('Distance < 33'), 'Distance')
# Out:
# count    18175.000000
# mean        10.105513
# std          5.309146
# min          0.000000
# 25%          6.200000
# 50%          9.700000
# 75%         13.000000
# max         32.300000
# Name: Distance, dtype: float64

# %% [markdown]
# **Получаем, что *абсолютное большинство* живёт от 6 до 13 км от центра**

# %% [markdown]
# #### Postcode - Почтовый индекс

# %%
hist_box_describe_num(train, 'Postcode')
# Out:
# count    18373.000000
# mean      3107.258314
# std         95.285542
# min       3000.000000
# 25%       3046.000000
# 50%       3085.000000
# 75%       3149.000000
# max       3978.000000
# Name: Postcode, dtype: float64

# %% [markdown]
# **Большинство почтовых индексов находятся от 3000 до 3200-ого**

# %% [markdown]
# #### Bedroom2 - Количество спален

# %%
hist_box_describe_num(train, 'Bedroom2')
# Out:
# count    14905.000000
# mean         2.914928
# std          0.962743
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         20.000000
# Name: Bedroom2, dtype: float64

# %% [markdown]
# **В большинстве домов от 1 до 4 спален**

# %% [markdown]
# #### Bathroom - Количество ванных комнат

# %%
hist_box_describe_num(train, 'Bathroom')
# Out:
# count    14903.000000
# mean         1.538683
# std          0.688374
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          8.000000
# Name: Bathroom, dtype: float64

# %% [markdown]
# **Большинство домов имеет от 0 до 3 ванных комнат**

# %% [markdown]
# #### Car - Количество парковочных мест:

# %%
hist_box_describe_num(train, 'Car')
# Out:
# count    14798.000000
# mean         1.617313
# std          0.957072
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         10.000000
# Name: Car, dtype: float64

# %% [markdown]
# **В большинстве домов от 0 до 3 парковочных мест**

# %% [markdown]
# #### Landsize - Площадь прилегающей территории

# %%
hist_box_describe_num(train, 'Landsize')
# Out:
# count     13579.000000
# mean        558.937403
# std        3991.516323
# min           0.000000
# 25%         177.000000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %% [markdown]
# **В данной категории много выбросов**
# **Можно считать выбросами всё, где прилегающая территория больше 1750. Таких объектов 277, что около 2%.**

# %%
hist_box_describe_num(train.query('Landsize < 1750'), 'Landsize')
# Out:
# count    13301.000000
# mean       422.445380
# std        301.055625
# min          0.000000
# 25%        172.000000
# 50%        422.000000
# 75%        645.000000
# max       1730.000000
# Name: Landsize, dtype: float64

# %% [markdown]
# **Существует множество домов без прилегающей территории, а так же большинство домов имеет прилегающую территорию от 0 до 1350 м²**

# %% [markdown]
# #### BuildingArea - Площадь дома

# %%
hist_box_describe_num(train, 'BuildingArea')
# Out:
# count     7750.000000
# mean       151.133167
# std        519.517626
# min          0.000000
# 25%         93.000000
# 50%        126.000000
# 75%        173.862500
# max      44515.000000
# Name: BuildingArea, dtype: float64

# %% [markdown]
# **Есть выбросы**
# **Можно считать выбросами объекты, где площадь дома более 600 м². Таких объектов ≈0.5%**

# %%
hist_box_describe_num(train.query('BuildingArea < 600'), 'BuildingArea')
# Out:
# count    7713.000000
# mean      141.001453
# std        75.294717
# min         0.000000
# 25%        92.000000
# 50%       125.000000
# 75%       172.000000
# max       594.000000
# Name: BuildingArea, dtype: float64

# %% [markdown]
# **Большинство домов имеют площадь от 0 до 300 м²**

# %% [markdown]
# #### YearBuilt - Год постройки

# %%
hist_box_describe_num(train, 'YearBuilt')
# Out:
# count    8944.000000
# mean     1965.925089
# std        36.958956
# min      1196.000000
# 25%      1950.000000
# 50%      1970.000000
# 75%      2000.000000
# max      2018.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# **Выбросы**
# **Можно считать выбросами объекты, год постройки которых старше 1875. Таких объектов ≈0.2%**

# %%
hist_box_describe_num(train.query('YearBuilt > 1875'), 'YearBuilt')
# Out:
# count    8921.000000
# mean     1966.271494
# std        35.709928
# min      1877.000000
# 25%      1950.000000
# 50%      1970.000000
# 75%      2000.000000
# max      2018.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# **Большинство домов построены в период с 1950 по 2000 годы**

# %% [markdown]
# #### Lattitude - Широта

# %%
hist_box_describe_num(train, 'Lattitude')
# Out:
# count    15041.000000
# mean       -37.809872
# std          0.081272
# min        -38.182550
# 25%        -37.858180
# 50%        -37.803600
# 75%        -37.756100
# max        -37.408530
# Name: Lattitude, dtype: float64

# %% [markdown]
# **Дома чаще всего находятся между -38 и -37.6 широтой**

# %% [markdown]
# #### Longtitude - Долгота

# %%
hist_box_describe_num(train, 'Longtitude')
# Out:
# count    15041.000000
# mean       144.996486
# std          0.106536
# min        144.431810
# 25%        144.931400
# 50%        145.001100
# 75%        145.060190
# max        145.526350
# Name: Longtitude, dtype: float64

# %% [markdown]
# **Большинство домов между 144.7 и 145.3 долготой**

# %% [markdown]
# #### Propertycount - Количество объектов недвижимости в одном районе

# %%
hist_box_describe_num(train, 'Propertycount')
# Out:
# count    18372.000000
# mean      7518.621489
# std       4487.143499
# min        249.000000
# 25%       4294.000000
# 50%       6567.000000
# 75%      10331.000000
# max      21650.000000
# Name: Propertycount, dtype: float64

# %% [markdown]
# **В одном районе может быть от 0 до 17 тысяч объектов недвижимости**

# %% [markdown]
# #### id

# %%
hist_box_describe_num(train, 'id')
# Out:
# count    18373.000000
# mean     17490.731889
# std      10075.864589
# min          2.000000
# 25%       8749.000000
# 50%      17497.000000
# 75%      26286.000000
# max      34856.000000
# Name: id, dtype: float64

# %% [markdown]
# **id расположены равномерно от 2 до ≈35000**

# %% [markdown]
# #### Описание количественных переменных

# %% [markdown]
# **1.** Минимальная цена продажи - 227 000, Максимальная - 5 580 000, Средняя ≈ 1 053 000, Медианная ≈ 880 000
# **2.** Минимальное количество комнат - 1, Максимальное - 12, Среднее и Медианное ≈ 3
# **3. Квартиры располагаются в радиусе 48 км от центра:** Минимальное расстояние до центра - 0, Максимальное - 48км, Среднее и Медианное ≈ 10км
# **4. Квартиры могут продаваться без спален:** Минимальное кол-во спален - 0, Максимальное - 20, Медианное и Среднее ≈ 3
# **5. Квартиры могут продаваться без ванных:** Минимальное кол-во ванных - 0, Максимальное - 8, Среднее - 1.5, Медианное - 1
# **6. Квартиры могут продаваться без парковочных мест:** Минимальное кол-во парковок - 0, Максимальное - 10, Среднее - 1.6, Медианное - 2
# **7. Объекты могут продаваться без прилегающей территории:** Минимальная прилегающая территория - 0, Максимальная - 433014 м² (**ВЫБРОС!**), Средняя - 558 м², Медианная - 440 м²
# **8.** Минимальная жилая площадь - 0 (Возможно студии???), Максимальная ≈ 44000 м² (**ВЫБРОС!!**), Средняя - 151 м², Медианная - 126м
# **9.** Минимальный год постройки - 1196 (**ВЫБРОС!!!**), Максимальный - 2018, Средний - 1966, Медианный - 1970

# %% [markdown]
# #### Корреляция

# %%
msno.heatmap(train);

# %%
correlation_matrix = np.round(train.corr(),2)
fig = plt.figure(figsize=(8, 8))
sns.heatmap(data=correlation_matrix, annot=True);
# Out:
# C:\Users\Zetis\AppData\Local\Temp\ipykernel_27628\4069816509.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = np.round(train.corr(),2)

# %% [markdown]
# **Больше всего коррелирует друг с другом:**
# 1. Количество комнат и количество спален
# 2. Количество комнат и количество ванных
# 3. Количество спален и количество ванных
# 4. Площадь дома и площадь прилегающей территории

# %%
from feature_engine.selection import SmartCorrelatedSelection

# %%
correlated = SmartCorrelatedSelection(
    variables= None,
    method = 'pearson',
    threshold = 0.8,
    missing_values = 'ignore',
    selection_method = 'variance',
    estimator=None,
    scoring = 'roc_auc',
    cv=5)

correlated.fit(train)
# Out:
# SmartCorrelatedSelection(cv=5, selection_method='variance')

# %%
correlated.features_to_drop_
# Out:
# ['Rooms']

# %% [markdown]
# **Библиотека feature-engine предлагает дропнуть переменную Rooms, т.к. она больше всех коррелирует с другими и может помешать в дальнейшем в ML**

# %% [markdown]
# ### Категориальные признаки

# %% [markdown]
# **Краткая сводка**

# %%
train.describe(include='object').T
# Out:
#              count unique                      top   freq
# Suburb       18373    329                Reservoir    540
# Address      18373  18112              28 Blair St      3
# Type         18373      3                        h  12091
# Method       18373      5                        S  12025
# SellerG      18373    305                   Nelson   2001
# CouncilArea  18372     33  Boroondara City Council   1896
# Regionname   18372      8    Southern Metropolitan   6326

# %%
cat_features
# Out:
# ['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'CouncilArea', 'Regionname']

# %% [markdown]
# **Функция для категориальных признаков**

# %%
def describe_cat(ds, x):
    print('Number of unique values:', ds[x].nunique())
    print(ds[x].value_counts())

# %% [markdown]
# #### Suburb - Район (микрорайон)

# %%
describe_cat(train, 'Suburb')
# Out:
# Number of unique values: 329
# Reservoir         540
# Bentleigh East    368
# Richmond          333
# Preston           312
# Brunswick         285
#                  ...
# Wonga Park          1
# Upwey               1
# Bacchus Marsh       1
# Rockbank            1
# Monbulk             1
# Name: Suburb, Length: 329, dtype: int64

# %%
sns.countplot(data=train, x='Suburb');

# %% [markdown]
# **Т.к. районов более 300, сложно их обобщить**

# %% [markdown]
# **Топ 10 дорогих микрорайонов**

# %%
train.groupby('Suburb').Price.median().sort_values(ascending=False).head(10)
# Out:
# Suburb
# Canterbury      1992500.0
# Albert Park     1875000.0
# Middle Park     1850000.0
# Camberwell      1845000.0
# Balwyn          1800000.0
# Eaglemont       1750000.0
# Ivanhoe East    1740000.0
# Kew East        1725000.0
# Brighton        1713000.0
# Princes Hill    1700000.0
# Name: Price, dtype: float64

# %% [markdown]
# **Топ 10 дешёвых микрорайонов**

# %%
train.groupby('Suburb').Price.median().sort_values().head(10)
# Out:
# Suburb
# Bacchus Marsh      285000.0
# Rockbank           340000.0
# Kurunjang          353500.0
# Werribee South     355000.0
# Wallan             366000.0
# Melton South       375000.0
# Melton             402500.0
# Melton West        421250.0
# Diggers Rest       435000.0
# Cranbourne East    440000.0
# Name: Price, dtype: float64

# %% [markdown]
# #### Address - Адрес

# %%
describe_cat(train, 'Address')
# Out:
# Number of unique values: 18112
# 28 Blair St         3
# 36 Aberfeldie St    3
# 7 Churchill Av      3
# 1/1 Clarendon St    3
# 5 Margaret St       3
#                    ..
# 8/67 High St        1
# 5/2 Karbarook Av    1
# 5/60 Chomley St     1
# 20a Park Rd         1
# 42 Pascoe St        1
# Name: Address, Length: 18112, dtype: int64

# %% [markdown]
# **Практически каждый адрес уникален, по этом нет смысла строить гистограмму**

# %% [markdown]
# #### Type - Тип дома

# %%
describe_cat(train, 'Type')
# Out:
# Number of unique values: 3
# h    12091
# u     4275
# t     2007
# Name: Type, dtype: int64

# %%
sns.countplot(data=train, x='Type');

# %% [markdown]
# **Больше всего домов типа h - дома, виллы, коттеджи. В середине u - дуплексы. Меньше всего t - таунхаусы.**

# %%
sns.boxplot(data=train, x='Type', y='Price');

# %% [markdown]
# **Самые дорогие - h (коттеджи), дешевле - t (таунхаусы), самые дешёвые - u (дуплексы)**

# %% [markdown]
# #### Method - метод продажи

# %%
describe_cat(train, 'Method')
# Out:
# Number of unique values: 5
# S     12025
# SP     2353
# PI     2179
# VB     1688
# SA      128
# Name: Method, dtype: int64

# %%
sns.countplot(data=train, x='Method');

# %%
sns.boxplot(data=train, x='Method', y='Price');

# %% [markdown]
# **Всего 5 вариантов продажи, больше всего было продано с помощью S - обычная продажа**

# %%
# plt.figure(figsize=(10,5))
# train[train['Method']=='S']['Price'].hist(alpha=0.5, color='green',bins=30, label='Type S')
# train[train['Method']=='SP']['Price'].hist(alpha=0.5, color='yellow',bins=30, label='Type SP')
# train[train['Method']=='PI']['Price'].hist(alpha=0.5, color='blue',bins=30, label='Type PI')
# train[train['Method']=='VB']['Price'].hist(alpha=0.5, color='red',bins=30, label='Type VB')
# train[train['Method']=='SA']['Price'].hist(alpha=0.5, color='white',bins=30, label='Type SA')
#
# plt.ylabel('Price')
# plt.xlabel('Number of observations')
# plt.legend()
# plt.show()

# %% [markdown]
# #### SellerG - Агент по недвижимости

# %%
describe_cat(train, 'SellerG')
# Out:
# Number of unique values: 305
# Nelson           2001
# Jellis           1756
# hockingstuart    1579
# Barry            1392
# Ray              1033
#                  ...
# Zahn                1
# Homes               1
# Allan               1
# Steveway            1
# Point               1
# Name: SellerG, Length: 305, dtype: int64

# %%
sns.countplot(data=train, x='SellerG');

# %% [markdown]
# **Всего 305 агентов недвижимости. Лучшие из них продали более 1000 объектов**

# %% [markdown]
# #### CouncilArea - Округа

# %%
describe_cat(train, 'CouncilArea')
# Out:
# Number of unique values: 33
# Boroondara City Council           1896
# Darebin City Council              1714
# Moreland City Council             1335
# Glen Eira City Council            1251
# Moonee Valley City Council        1161
# Melbourne City Council            1159
# Banyule City Council               947
# Maribyrnong City Council           898
# Brimbank City Council              874
# Bayside City Council               857
# Port Phillip City Council          729
# Yarra City Council                 683
# Stonnington City Council           674
# Monash City Council                640
# Hobsons Bay City Council           601
# Manningham City Council            558
# Hume City Council                  481
# Kingston City Council              410
# Whittlesea City Council            303
# Whitehorse City Council            237
# Wyndham City Council               188
# Maroondah City Council             165
# Knox City Council                  138
# Frankston City Council             114
# Melton City Council                101
# Greater Dandenong City Council      95
# Casey City Council                  74
# Yarra Ranges Shire Council          32
# Nillumbik Shire Council             25
# Macedon Ranges Shire Council        17
# Cardinia Shire Council              13
# Moorabool Shire Council              1
# Mitchell Shire Council               1
# Name: CouncilArea, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=80)
sns.countplot(data=train, x='CouncilArea');

# %% [markdown]
# **Всего 33 округа, количество домов расположено неравномерно**

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=80)
sns.boxplot(data=train, x='CouncilArea', y='Price');

# %% [markdown]
# **Некоторые округа сильно дороже других**

# %% [markdown]
# **Топ 10 дорогих округов**

# %%
train.groupby('CouncilArea').Price.median().sort_values(ascending=False).head(10)
# Out:
# CouncilArea
# Boroondara City Council       1581000.0
# Bayside City Council          1450000.0
# Stonnington City Council      1254000.0
# Manningham City Council       1200000.0
# Monash City Council           1133000.0
# Glen Eira City Council        1100000.0
# Whitehorse City Council       1095000.0
# Yarra City Council            1032000.0
# Moonee Valley City Council     950000.0
# Kingston City Council          921000.0
# Name: Price, dtype: float64

# %% [markdown]
# **Топ 10 дешёвых округов**

# %%
train.groupby('CouncilArea').Price.median().sort_values().head(10)
# Out:
# CouncilArea
# Moorabool Shire Council    285000.0
# Mitchell Shire Council     366000.0
# Melton City Council        430000.0
# Wyndham City Council       530000.0
# Cardinia Shire Council     559000.0
# Hume City Council          570500.0
# Whittlesea City Council    601000.0
# Casey City Council         625000.0
# Frankston City Council     642500.0
# Brimbank City Council      650000.0
# Name: Price, dtype: float64

# %% [markdown]
# #### Regionname - Административное деление (Запад, Северо-запад и т.д.)

# %%
describe_cat(train, 'Regionname')
# Out:
# Number of unique values: 8
# Southern Metropolitan         6326
# Northern Metropolitan         5305
# Western Metropolitan          3875
# Eastern Metropolitan          1999
# South-Eastern Metropolitan     683
# Eastern Victoria                79
# Northern Victoria               63
# Western Victoria                42
# Name: Regionname, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=15)
sns.countplot(data=train, x='Regionname');

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=15)
sns.boxplot(data=train, x='Regionname', y='Price');

# %% [markdown]
# **Всего 8 Административных округов. В округе Southern Metropolitan продаётся самая дорогая недвижимость**

# %% [markdown]
# **Топ дорогих Административных округов**

# %%
train.groupby('Regionname').Price.median().sort_values(ascending=False)
# Out:
# Regionname
# Southern Metropolitan         1225000.0
# Eastern Metropolitan          1000500.0
# South-Eastern Metropolitan     815000.0
# Northern Metropolitan          765000.0
# Western Metropolitan           765000.0
# Eastern Victoria               689000.0
# Northern Victoria              547000.0
# Western Victoria               388750.0
# Name: Price, dtype: float64

# %% [markdown]
# **Топ дешёвых Административных округов**

# %%
train.groupby('Regionname').Price.median().sort_values()
# Out:
# Regionname
# Western Victoria               388750.0
# Northern Victoria              547000.0
# Eastern Victoria               689000.0
# Northern Metropolitan          765000.0
# Western Metropolitan           765000.0
# South-Eastern Metropolitan     815000.0
# Eastern Metropolitan          1000500.0
# Southern Metropolitan         1225000.0
# Name: Price, dtype: float64

# %% [markdown]
# **Продажи по годам: 2016 и 2017**

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=15)
sns.boxplot(x='Regionname',y='Price', data=train[train['YearBuilt']==2016])
plt.title('Region Name Vs Price for year 2016')
plt.figure(figsize=(10,5))
sns.boxplot(x='Regionname',y='Price', data=train[train['YearBuilt']==2017])
plt.title('Region Name Vs Price for year 2017')
# Out:
# Text(0.5, 1.0, 'Region Name Vs Price for year 2017')

# %% [markdown]
# #### Описание категориальных переменных

# %% [markdown]
# **1.** Чаще всего продаются объекты типа h: коттеджи, виллы, дома и т.д.
# **2.** Больше всего объектов продаётся в районе Reservoir - 540
# **3.** Больше всего объектов продаётся в округе Boroondara City - 1896
# **4.** Больше всего объектов продаётся в Административном округе Southern Metropolitan - 6326

# %% [markdown]
# ## Пропуски

# %%
train.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         0.188755
# Bathroom         0.188864
# Car              0.194579
# Landsize         0.260926
# BuildingArea     0.578185
# YearBuilt        0.513199
# CouncilArea      0.000054
# Lattitude        0.181353
# Longtitude       0.181353
# Regionname       0.000054
# Propertycount    0.000054
# id               0.000000
# dtype: float64

# %%
msno.bar(train);

# %% [markdown]
# **1. В трейне (обучающей) присутствуют более 50% пропусков в YearBuilt и BuildingArea, скорее всего эти колонки придётся выкинуть
# 2. Для других колонок пропущенных значений меньше, по этому можно будет воспользоваться случайными значениями вместо пропусков**

# %%
test.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000113
# Postcode         0.000113
# Bedroom2         0.335677
# Bathroom         0.336131
# Car              0.366977
# Landsize         0.504990
# BuildingArea     0.673169
# YearBuilt        0.647086
# CouncilArea      0.000227
# Lattitude        0.330007
# Longtitude       0.330007
# Regionname       0.000227
# Propertycount    0.000227
# id               0.000000
# dtype: float64

# %%
msno.bar(test);

# %%
ввввввввввввввввввввв
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 ввввввввввввввввввввв
#
# NameError: name 'ввввввввввввввввввввв' is not defined

# %% [markdown]
# ### Вариант №1: Заполнить все пропуски случайными значениями

# %%
train_v1 = train
test_v1 = test

# %%
y_v1 = train_v1.Price
train_v1 = train_v1.drop('Price', axis=1)

# %%
from feature_engine.imputation import RandomSampleImputer

# %%
random_inputer = RandomSampleImputer(variables=['Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount', 'CouncilArea', 'Regionname'])
random_inputer.fit(train_v1)

# %%
train_v1 = random_inputer.transform(train_v1)
test_v1 = random_inputer.transform(test_v1)

# %% [markdown]
# **Проверка, остались ли пропуски**

# %%
train_v1.isna().mean()

# %%
train_v1.isna().sum()

# %% [markdown]
# **В трейне(в1) больше нет пропусков ↑**

# %%
test_v1.isna().mean()

# %%
test_v1.isna().sum()

# %% [markdown]
# **В тесте остались пропуски!!! ↑ 1 пропуск в колонке Distance и 1 в колонке Postcode**

# %% [markdown]
# **Посмотрю пропуски:**

# %%
test_v1[test_v1.Distance.isna()]

# %% [markdown]
# **Заменю пропуски медианными значениями с помощью fillna:**

# %%
test_v1['Distance'] = test_v1.Distance.fillna(test_v1.Distance.median())
test_v1['Postcode'] = test_v1.Postcode.fillna(test_v1.Postcode.median())

# %%
test_v1.isna().sum()

# %% [markdown]
# **Теперь ПРОПУСКИ ОТСУТСТВУЮТ!!!**

# %% [markdown]
# ### Вариант №2 заполнить пропуски случайными значениями и убрать выбросы

# %%
train_v1 = train
test_v1 = test

# %%
y_v1 = train_v1.Price
train_v1 = train_v1.drop('Price', axis=1)

# %%
from feature_engine.imputation import RandomSampleImputer

# %%
random_inputer = RandomSampleImputer(variables=['Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount', 'CouncilArea', 'Regionname'])
random_inputer.fit(train_v1)
# Out:
# RandomSampleImputer(variables=['Bedroom2', 'Bathroom', 'Car', 'Landsize',
#                                'BuildingArea', 'YearBuilt', 'Lattitude',
#                                'Longtitude', 'Propertycount', 'CouncilArea',
#                                'Regionname'])

# %%
train_v1 = random_inputer.transform(train_v1)
test_v1 = random_inputer.transform(test_v1)

# %% [markdown]
# **Проверка, остались ли пропуски**

# %%
train_v1.isna().mean()
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# BuildingArea     0.0
# YearBuilt        0.0
# CouncilArea      0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# id               0.0
# dtype: float64

# %%
train_v1.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# id               0
# dtype: int64

# %% [markdown]
# **В трейне(в1) больше нет пропусков ↑**

# %%
test_v1.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000113
# Postcode         0.000113
# Bedroom2         0.000000
# Bathroom         0.000000
# Car              0.000000
# Landsize         0.000000
# BuildingArea     0.000000
# YearBuilt        0.000000
# CouncilArea      0.000000
# Lattitude        0.000000
# Longtitude       0.000000
# Regionname       0.000000
# Propertycount    0.000000
# id               0.000000
# dtype: float64

# %%
test_v1.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         1
# Postcode         1
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# id               0
# dtype: int64

# %%
test_v1['Distance'] = test_v1.Distance.fillna(test_v1.Distance.median())
test_v1['Postcode'] = test_v1.Postcode.fillna(test_v1.Postcode.median())

# %%
test_v1.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# id               0
# dtype: int64

# %% [markdown]
# **Теперь ПРОПУСКИ ОТСУТСТВУЮТ!!!**

# %% [markdown]
# **Возвращаю target = Price**

# %%
train_v1.shape
# Out:
# (18373, 22)

# %%
train_v1 = train_v1.merge(y_v1, left_index=True, right_index=True)

# %%
train_v1.shape
# Out:
# (18373, 22)

# %% [markdown]
# #### Landsize - прилегающая территория

# %% [markdown]
# **Максимальная - 433014 м² (ВЫБРОС!), Средняя - 558 м², Медианная - 444 м²**
# **Можно считать выбросами всё, где прилегающая территория больше 1750. Таких объектов 277, что около 2%.**

# %%
hist_box_describe_num(train_v1, 'Landsize')
# Out:
# count     18373.000000
# mean        547.340064
# std        3489.234051
# min           0.000000
# 25%         173.000000
# 50%         435.000000
# 75%         650.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
hist_box_describe_num(train_v1.query('Landsize < 1750'), 'Landsize')
# Out:
# count    17999.000000
# mean       419.934219
# std        301.992158
# min          0.000000
# 25%        169.000000
# 50%        417.000000
# 75%        644.000000
# max       1730.000000
# Name: Landsize, dtype: float64

# %%
train_v1 = train_v1.query('Landsize < 1750')

# %%
train_v1.shape
# Out:
# (17999, 22)

# %% [markdown]
# #### BuildingArea

# %% [markdown]
# **Максимальная ≈ 44000 м² (ВЫБРОС!!), Средняя - 151 м², Медианная - 126м**
# **Можно считать выбросами всё, где площадь больше 600 м². Таких объектов 80, ≈ 0.4%**

# %%
hist_box_describe_num(train_v1, 'BuildingArea')
# Out:
# count    17999.000000
# mean       152.066997
# std        582.341946
# min          0.000000
# 25%         93.000000
# 50%        126.000000
# 75%        174.000000
# max      44515.000000
# Name: BuildingArea, dtype: float64

# %%
hist_box_describe_num(train_v1.query('BuildingArea < 600'), 'BuildingArea')
# Out:
# count    17919.000000
# mean       141.336861
# std         75.310090
# min          0.000000
# 25%         93.000000
# 50%        126.000000
# 75%        173.000000
# max        594.000000
# Name: BuildingArea, dtype: float64

# %%
train_v1 = train_v1.query('BuildingArea < 600')

# %%
train_v1.shape
# Out:
# (17919, 22)

# %% [markdown]
# #### YearBuilt

# %% [markdown]
# Минимальный год постройки - 1196 (**ВЫБРОС!!!**), Максимальный - 2018, Средний - 1966, Медианный - 1970

# %%
hist_box_describe_num(train_v1, 'YearBuilt')
# Out:
# count    17919.000000
# mean      1965.599364
# std         36.587940
# min       1196.000000
# 25%       1948.000000
# 50%       1970.000000
# 75%       2000.000000
# max       2018.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# **Выбросы**
# **Можно считать выбросами объекты, год постройки которых старше 1875. Таких объектов 44 ≈0.2%**

# %%
hist_box_describe_num(train_v1.query('YearBuilt > 1875'), 'YearBuilt')
# Out:
# count    17875.000000
# mean      1965.895385
# std         35.804270
# min       1877.000000
# 25%       1949.000000
# 50%       1970.000000
# 75%       2000.000000
# max       2018.000000
# Name: YearBuilt, dtype: float64

# %%
train_v1 = train_v1.query('YearBuilt > 1875')

# %%
train_v1.shape
# Out:
# (17875, 22)

# %% [markdown]
# **Самые крупные выбросы были устранены!!!**

# %% [markdown]
# ## Baseline

# %% [markdown]
# ### Baseline HL

# %%
ввввввввввввввввв

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error

# %% [markdown]
# **Возваращаю Price в трейн, т.к. Price был дропнут для заполнения пропусков**

# %%
train_v1 = train_v1.merge(y_v1, left_index=True, right_index=True)

# %%
train_v1

# %%
train_v1.Price.median()

# %%
def error(y_true, y_pred):
    print(mean_absolute_error(y_true, y_pred))
    print(mean_absolute_percentage_error(y_true, y_pred))

# %%
ddddddddddddd

# %% [markdown]
# ### Baseline Catboost

# %%
train_v1.head()
# Out:
#        Suburb           Address  Rooms Type Method SellerG       Date  \
# 0  Abbotsford      85 Turner St      2    h      S  Biggin 2016-12-03
# 1  Abbotsford   25 Bloomburg St      2    h      S  Biggin 2016-02-04
# 2  Abbotsford      5 Charles St      3    h     SP  Biggin 2017-03-04
# 3  Abbotsford  40 Federation La      3    h     PI  Biggin 2017-03-04
# 4  Abbotsford       55a Park St      4    h     VB  Nelson 2016-06-04
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0         105.0
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0         126.0
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0     1965.0  Yarra City Council   -37.7996    144.9984
# 1     1900.0  Yarra City Council   -37.8079    144.9934
# 2     1900.0  Yarra City Council   -37.8093    144.9944
# 3     1970.0  Yarra City Council   -37.7969    144.9969
# 4     2014.0  Yarra City Council   -37.8072    144.9941
#
#               Regionname  Propertycount     id      Price
# 0  Northern Metropolitan         4019.0  34302  1480000.0
# 1  Northern Metropolitan         4019.0  33247  1035000.0
# 2  Northern Metropolitan         4019.0  31886  1465000.0
# 3  Northern Metropolitan         4019.0  18999   850000.0
# 4  Northern Metropolitan         4019.0  16809  1600000.0

# %% [markdown]
# #### Валидационная выборка

# %%
from sklearn.model_selection import train_test_split

# %%
from catboost import CatBoostRegressor

# %%
# val_cat, test_cat = train_test_split(train_v1, random_state=42, train_size=0.5)

# %%
train_v1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount', 'id', 'Price'],
#       dtype='object')

# %%
X = [i for i in train_v1.columns]
cat_features1 = cat_features
y = ['Price']

# %%
X.remove('Price')

# %% [markdown]
# **Удаление ненужных данных**

# %%
X.remove('Date')
# X.remove('Address')
# X.remove('id')
# X.remove('Lattitude')
# X.remove('Longtitude')
# X.remove('Rooms')  # Рекомендация SmartCorrelatedSelection (Rooms)
# X.remove('Bedroom2')

# %%
print(X)
# Out:
# ['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount', 'id']

# %%
# cat_features1.remove('Address')

# %%
cat_features
# Out:
# ['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'CouncilArea', 'Regionname']

# %% [markdown]
# #### Обучение

# %%
parameters = {'cat_features': cat_features,
              'eval_metric': 'MAPE',
              'loss_function': 'MAE',
              'random_seed': 42,
              'verbose':100}

# %%
model = CatBoostRegressor(**parameters)

# %%
model.fit(train_v1[X], train_v1[y])
# Out:
# 0:	learn: 0.4162762	total: 45ms	remaining: 45s
# 100:	learn: 0.1849137	total: 5.14s	remaining: 45.7s
# 200:	learn: 0.1694898	total: 9.31s	remaining: 37s
# 300:	learn: 0.1627632	total: 14.2s	remaining: 32.9s
# 400:	learn: 0.1568093	total: 19.4s	remaining: 29s
# 500:	learn: 0.1525330	total: 23.8s	remaining: 23.7s
# 600:	learn: 0.1491183	total: 27.5s	remaining: 18.3s
# 700:	learn: 0.1463856	total: 31.3s	remaining: 13.3s
# 800:	learn: 0.1440567	total: 35s	remaining: 8.7s
# 900:	learn: 0.1418804	total: 38.8s	remaining: 4.27s
# 999:	learn: 0.1400543	total: 42.6s	remaining: 0us

# %% [markdown]
# Вариант 1 (drop date): 0.05 - 0.1475, 0.03 - 0.1575, 0.07 - 0.1412, 0.1 - 0.1336, 0.2 - 0.1158, 0.3 - 0.1035

# %%
model.predict(test_v1[X])
# Out:
# array([ 864042.14055532, 1461993.97708124, 1355783.51809946, ...,
#         665837.35918867,  953368.43276444,  786190.4686335 ])

# %%
y_pred = model.predict(test_v1[X])

# %% [markdown]
# **Сохранение в CSV**

# %%
submission = pd.DataFrame(test_v1['id'])
submission['Price'] = y_pred
submission.to_csv('Cat_LR-auto_LF-MAE_Drop_date_DropEmi_Ls_BA_YB.csv', index=False)

# %%
# submission.to_csv('Cat_LR-01_LF-MAE_Drop_bedroom2_date_address_id_latitude_longtitude_DropEmi_Ls_BA_YB.csv', index=False)

# %%
submission.head()
# Out:
#       id         Price
# 0  30130  8.640421e+05
# 1  18311  1.461994e+06
# 2  18934  1.355784e+06
# 3   1824  8.258709e+05
# 4  31339  7.654320e+05

# %% [markdown]
# ### Baseline Catboost CV

# %%
X = [i for i in train_v1.columns]
cat_features = cat_features
y = ['Price']

# %%
X.remove('Price')

# %%
X.remove('Date')

# %%
print(X)

# %%
cat_features

# %% [markdown]
# #### Обучение

# %%
parameters = {'cat_features': cat_features,
              'learning_rate': 0.05,
              'eval_metric': 'MAPE',
              'loss_function': 'RMSE',
              'random_seed': 42,
              'verbose':100}

# %%
from catboost import Pool

# %%
train_full_data = Pool(train_v1[X],
                       label=train_v1[y],
                       cat_features=cat_features)

# %%
from catboost import cv

# %%
cv_data = cv(
    params = parameters,
    pool = train_full_data,
    fold_count=5,
    shuffle=True,
    partition_random_seed=0,
    stratified=False,
    verbose=False

)

# %%
cv_data

# %%
cv_data[cv_data['test-RMSE-mean'] == cv_data['test-RMSE-mean'].min()]

# %%
n_iters = cv_data[cv_data['test-RMSE-mean'] == cv_data['test-RMSE-mean'].min()]['iterations'].values[0]

# %%
n_iters

# %%
parameters = {'cat_features': cat_features,
              'learning_rate': 0.1,
              'iterations': n_iters,
              'eval_metric': 'MAPE',
              'loss_function': 'RMSE',
              'random_seed': 42,
              'verbose':100}

# %%
model = CatBoostRegressor(**parameters)

# %%
model.fit(train_v1[X], train_v1[y])

# %%
model.predict(test_v1[X])

# %%
y_pred = model.predict(test_v1[X])

# %% [markdown]
# **Сохранение в CSV**

# %%
submission = pd.DataFrame(test_v1['id'])
submission['Price'] = y_pred
submission.to_csv('Catboost_CV_lossf-RMSE.csv', index=False)

# %%
submission.head()
